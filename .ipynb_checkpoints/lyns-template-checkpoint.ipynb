# %% [markdown]
# # Your Title Here
#
# **Name(s)**: Landon Marchetti and Lyn Mansfield
#
# **Website Link**: (your website link)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from matplotlib.backends.backend_pdf import PdfPages

import plotly.express as px
pd.options.plotting.backend = 'plotly'

from dsc80_utils import * # Feel free to uncomment and use this.

# %% [markdown]
# ## Step 1: Introduction

# %% [markdown]
# # TODO
#
# Which legends are the most meta-defining? Difference in win rate between when it's banned vs when it's not
#
# How important is the first kill of a game?
#
# Which characters are the most banned? Which characters are the best?
#
# What archetype of character's performance matters the most?
#
# How important is early success?

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %% [markdown]
# # TODO
# What are "partial" rows missing from their data? <== me!

# %%
# TODO

from pathlib import Path

dataset_path = Path("./data/2025_LoL_esports_match_data_from_OraclesElixir.csv")
# /data/2025_LoL_esports_match_data_from_OraclesElixir.csv
test_s = open(dataset_path).read()
rows = test_s.split('\n')
columnss = rows[0].split(',')
rowss = [x.split(',') for x in rows[1:]]
data = pd.DataFrame(columns = columnss, data = rowss)

# %%
sample = data.iloc[:192]
sample
# Out:
#                  gameid datacompleteness  \
# 0      LOLTMNT03_179647         complete
# 1      LOLTMNT03_179647         complete
# 2      LOLTMNT03_179647         complete
# ..                  ...              ...
# 189  11716-11716_game_1          partial
# 190  11716-11716_game_1          partial
# 191  11716-11716_game_1          partial
#
#                                               url league  ... deathsat25  \
# 0                                                   LFL2  ...          2
# 1                                                   LFL2  ...          2
# 2                                                   LFL2  ...          2
# ..                                            ...    ...  ...        ...
# 189  https://lpl.qq.com/es/stats.shtml?bmid=11716    LPL  ...
# 190  https://lpl.qq.com/es/stats.shtml?bmid=11716    LPL  ...
# 191  https://lpl.qq.com/es/stats.shtml?bmid=11716    LPL  ...
#
#     opp_killsat25 opp_assistsat25 opp_deathsat25
# 0               2               4              2
# 1               1               7              0
# 2               1               5              1
# ..            ...             ...            ...
# 189
# 190
# 191
#
# [192 rows x 161 columns]

# %%
complete_samples = sample.query("datacompleteness == 'complete'")
partial_samples = sample.query("datacompleteness == 'partial'")

partial_samples = partial_samples.replace(to_replace='', value=np.nan)
partial_samples
# Out:
# /var/folders/rw/zlpzjq8n3g99ydqldhcp95qh0000gn/T/ipykernel_5993/3733244819.py:4: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#                  gameid datacompleteness  \
# 48   11715-11715_game_1          partial
# 49   11715-11715_game_1          partial
# 50   11715-11715_game_1          partial
# ..                  ...              ...
# 189  11716-11716_game_1          partial
# 190  11716-11716_game_1          partial
# 191  11716-11716_game_1          partial
#
#                                               url league  ... deathsat25  \
# 48   https://lpl.qq.com/es/stats.shtml?bmid=11715    LPL  ...        NaN
# 49   https://lpl.qq.com/es/stats.shtml?bmid=11715    LPL  ...        NaN
# 50   https://lpl.qq.com/es/stats.shtml?bmid=11715    LPL  ...        NaN
# ..                                            ...    ...  ...        ...
# 189  https://lpl.qq.com/es/stats.shtml?bmid=11716    LPL  ...        NaN
# 190  https://lpl.qq.com/es/stats.shtml?bmid=11716    LPL  ...        NaN
# 191  https://lpl.qq.com/es/stats.shtml?bmid=11716    LPL  ...        NaN
#
#     opp_killsat25 opp_assistsat25 opp_deathsat25
# 48            NaN             NaN            NaN
# 49            NaN             NaN            NaN
# 50            NaN             NaN            NaN
# ..            ...             ...            ...
# 189           NaN             NaN            NaN
# 190           NaN             NaN            NaN
# 191           NaN             NaN            NaN
#
# [48 rows x 161 columns]

# %%
num_missing = partial_samples.apply(pd.isna).sum()
num_missing = num_missing / partial_samples.shape[0]
print(num_missing[num_missing == 0].sort_values().to_string())
print(num_missing[num_missing != 0].sort_values().to_string())
# Out:
# gameid                     0.0
# teamkills                  0.0
# teamdeaths                 0.0
# team kpm                   0.0
# ckpm                       0.0
# damagetochampions          0.0
# dpm                        0.0
# damagetakenperminute       0.0
# wardsplaced                0.0
# wpm                        0.0
# wardskilled                0.0
# wcpm                       0.0
# controlwardsbought         0.0
# visionscore                0.0
# vspm                       0.0
# totalgold                  0.0
# earnedgold                 0.0
# earned gpm                 0.0
# goldspent                  0.0
# monsterkills               0.0
# assists                    0.0
# deaths                     0.0
# kills                      0.0
# result                     0.0
# datacompleteness           0.0
# url                        0.0
# league                     0.0
# year                       0.0
# split                      0.0
# playoffs                   0.0
# date                       0.0
# game                       0.0
# patch                      0.0
# monsterkillsownjungle      0.0
# participantid              0.0
# position                   0.0
# teamname                   0.0
# teamid                     0.0
# ban1                       0.0
# ban2                       0.0
# ban3                       0.0
# ban4                       0.0
# ban5                       0.0
# gamelength                 0.0
# side                       0.0
# monsterkillsenemyjungle    0.0
# playername                  0.17
# earnedgoldshare             0.17
# total cs                    0.17
# minionkills                 0.17
# cspm                        0.17
# firstbloodkill              0.17
# damageshare                 0.17
# playerid                    0.17
# champion                    0.17
# pick5                       0.83
# pick1                       0.83
# heralds                     0.83
# opp_heralds                 0.83
# void_grubs                  0.83
# opp_void_grubs              0.83
# barons                      0.83
# opp_barons                  0.83
# firsttower                  0.83
# towers                      0.83
# opp_towers                  0.83
# gspd                        0.83
# inhibitors                  0.83
# pick2                       0.83
# pick4                       0.83
# dragons (type unknown)      0.83
# opp_inhibitors              0.83
# opp_dragons                 0.83
# dragons                     0.83
# firstdragon                 0.83
# firstblood                  0.83
# pick3                       0.83
# xpat20                      1.00
# opp_xpat15                  1.00
# opp_csat20                  1.00
# opp_csat15                  1.00
# golddiffat15                1.00
# opp_xpat20                  1.00
# xpdiffat15                  1.00
# killsat15                   1.00
# goldat20                    1.00
# assistsat15                 1.00
# deathsat15                  1.00
# opp_killsat15               1.00
# opp_assistsat15             1.00
# opp_goldat20                1.00
# csat20                      1.00
# csdiffat15                  1.00
# opp_deathsat15              1.00
# assistsat20                 1.00
# xpdiffat20                  1.00
# opp_killsat25               1.00
# deathsat25                  1.00
# assistsat25                 1.00
# killsat25                   1.00
# csdiffat25                  1.00
# xpdiffat25                  1.00
# golddiffat25                1.00
# opp_csat25                  1.00
# opp_xpat25                  1.00
# golddiffat20                1.00
# opp_goldat25                1.00
# xpat25                      1.00
# goldat25                    1.00
# opp_deathsat20              1.00
# opp_assistsat20             1.00
# opp_killsat20               1.00
# deathsat20                  1.00
# opp_goldat15                1.00
# killsat20                   1.00
# csdiffat20                  1.00
# csat25                      1.00
# csat15                      1.00
# csat10                      1.00
# goldat15                    1.00
# firstherald                 1.00
# opp_elders                  1.00
# elders                      1.00
# hextechs                    1.00
# chemtechs                   1.00
# oceans                      1.00
# clouds                      1.00
# mountains                   1.00
# infernals                   1.00
# opp_elementaldrakes         1.00
# elementaldrakes             1.00
# firstbloodvictim            1.00
# firstbloodassist            1.00
# pentakills                  1.00
# quadrakills                 1.00
# triplekills                 1.00
# doublekills                 1.00
# firstbaron                  1.00
# firstmidtower               1.00
# firsttothreetowers          1.00
# turretplates                1.00
# opp_deathsat10              1.00
# opp_assistsat10             1.00
# opp_killsat10               1.00
# deathsat10                  1.00
# assistsat10                 1.00
# killsat10                   1.00
# csdiffat10                  1.00
# xpdiffat10                  1.00
# xpat15                      1.00
# golddiffat10                1.00
# opp_xpat10                  1.00
# opp_goldat10                1.00
# opp_assistsat25             1.00
# xpat10                      1.00
# goldat10                    1.00
# gpr                         1.00
# damagemitigatedperminute    1.00
# opp_turretplates            1.00
# opp_csat10                  1.00
# opp_deathsat25              1.00

# %%
team_rows = complete_samples.query("playername == ''")
team_rows
# Out:
#                gameid datacompleteness url league  ... deathsat25  \
# 10   LOLTMNT03_179647         complete       LFL2  ...         10
# 11   LOLTMNT03_179647         complete       LFL2  ...          3
# 22    LOLTMNT06_96134         complete       LFL2  ...          8
# ..                ...              ...  ..    ...  ...        ...
# 167  LOLTMNT03_180652         complete       LCKC  ...          3
# 178  LOLTMNT03_180657         complete       LCKC  ...          7
# 179  LOLTMNT03_180657         complete       LCKC  ...          5
#
#     opp_killsat25 opp_assistsat25 opp_deathsat25
# 10             10              26              3
# 11              3               5             10
# 22              7              12             15
# ..            ...             ...            ...
# 167             3               9              3
# 178             7               7              5
# 179             5              10              7
#
# [24 rows x 161 columns]

# %%
w_first_blood = team_rows.query("firstblood == 1")
wo_first_blood = team_rows.query("firstblood == 0")

fig = px.histogram(w_first_blood, x='result')
fig.show()
# Out:
# <div>                            <div id="bea2fad1-d2ab-4b73-b957-5257ddc1a4af" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bea2fad1-d2ab-4b73-b957-5257ddc1a4af")) {                    Plotly.newPlot(                        "bea2fad1-d2ab-4b73-b957-5257ddc1a4af",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"result=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mes ...

# %% [markdown]
# ## Step 3: Assessment of Missingness

# %%
# TODO

def univariate_plots(df, title):
    pdf_pages = PdfPages(f'univariate_plots_{title}.pdf')

    plt.figure()

    for column in df.columns:
        fig, ax = plt.subplots()
        ax.hist(df[column])
        ax.set_title(f'Graph of {column}')
        pdf_pages.savefig(fig)
        plt.close(fig)
    
    pdf_pages.close()

def bivariate_plot(df, categorical_column, target_column, title):
    pdf_pages = PdfPage(f'bivariate_plots_{title}.pdf')

    plt.figure()
    
    for column in df.columns:
        fig, ax = plt.subplots()
        ax.hist(df[column])
        ax.set_title(f'Graph of {column}')
        pdf_pages.savefig(fig)
        plt.close(fig)
    
    pdf_pages.close()

# %%
df = pd.DataFrame({
	'A': np.random.uniform(0, 10, 100), 
	'B': np.random.uniform(0, 10, 100), 
	'C': np.random.uniform(0, 10, 100)
	})
univariate_plots(df, 'test')

# %% [markdown]
# ## Step 4: Hypothesis Testing

# %%
# TODO

# %% [markdown]
# ## Step 5: Framing a Prediction Problem

# %%
# TODO

# %% [markdown]
# ## Step 6: Baseline Model

# %%
# TODO

# %% [markdown]
# ## Step 7: Final Model

# %%
# TODO

# %% [markdown]
# ## Step 8: Fairness Analysis

# %%
# TODO
